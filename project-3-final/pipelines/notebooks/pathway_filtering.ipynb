# %%
import pandas as pd

# %%
df = pd.read_csv('../../data/interim/name_map.csv', sep=',')
df
# Out:
#                                          Query  \
# 0                      cis-4-hydroxy-d-proline
# 1                               phenyl acetate
# 2                                   putrescine
# 3                      ribose 1,5-bisphosphate
# 4                       gamma-glutamylcysteine
# ..                                         ...
# 128                                    inosine
# 129  1d-myo-inositol 1,4,5,6-tetrakisphosphate
# 130           1-palmitoylglycerophosphocholine
# 131                                    sucrose
# 132            3-(3,4-dihydroxyphenyl)pyruvate
#
#                                         Match         HMDB     PubChem  \
# 0                     cis-4-Hydroxy-D-proline  HMDB0060460    440014.0
# 1                              Phenyl acetate  HMDB0040733     31229.0
# 2                                  Putrescine  HMDB0001414      1045.0
# 3                     Ribose 1,5-bisphosphate  HMDB0011688  14035695.0
# ...

# %%
arginine = [
'C00011',
'C00014',
'C00025',
'C00026',
'C00049',
'C00062',
'C00064',
'C00077',
'C00086',
'C00122',
'C00169',
'C00327',
'C00437',
'C00624',
'C01010',
'C01250',
'C03406',
'C04133',
'C15532',
'C20948',
'C20949',
'C20950',
'C20951',
]

valine = [
'C00022',
'C00024',
'C00109',
'C00123',
'C00141',
'C00183',
'C00188',
'C00233',
'C00407',
'C00671',
'C02226',
'C02504',
'C02612',
'C02631',
'C04181',
'C04236',
'C04272',
'C04411',
'C06006',
'C06007',
'C06010',
'C06032',
'C14463',
]

phenylalanine = [
'C00022',
'C00024',
'C00042',
'C00079',
'C00082',
'C00084',
'C00091',
'C00122',
'C00166',
'C00423',
'C00512',
'C00582',
'C00596',
'C00601',
'C00642',
'C01198',
'C01772',
'C02137',
'C02232',
'C02265',
'C02505',
'C02763',
'C03519',
'C03589',
'C04044',
'C04148',
'C04479',
'C05332',
'C05593',
'C05598',
'C05607',
'C05629',
'C05852',
'C05853',
'C06207',
'C07086',
'C11457',
'C11588',
'C12621',
'C12622',
'C12623',
'C12624',
'C14144',
'C14145',
'C15524',
'C19945',
'C19946',
'C19975',
'C20062',
]

glutathione = [
'C00005',
'C00006',
'C00024',
'C00025',
'C00037',
'C00051',
'C00072',
'C00077',
'C00097',
'C00127',
'C00134',
'C00151',
'C00315',
'C00669',
'C00750',
'C01322',
'C01419',
'C01672',
'C01879',
'C02090',
'C02320',
'C03170',
'C03646',
'C03740',
'C05422',
'C05726',
'C05727',
'C05729',
'C05730',
'C16562',
'C16563',
'C16564',
'C16565',
'C16566',
'C16567',
'C16568',
'C16663',
'C16664',
]

tyrosine = [
'C00074',
'C00078',
'C00079',
'C00082',
'C00108',
'C00119',
'C00166',
'C00230',
'C00251',
'C00254',
'C00279',
'C00296',
'C00354',
'C00441',
'C00463',
'C00493',
'C00587',
'C00826',
'C00944',
'C01094',
'C01179',
'C01269',
'C01302',
'C02637',
'C03175',
'C03506',
'C04302',
'C00029',
'C00031',
'C00052',
'C00085',
'C00089',
'C00095',
'C00103',
'C00111',
'C00116',
'C00118',
'C00124',
'C00137',
'C00159',
'C00243',
'C00267',
'C00446',
'C00492',
'C00577',
'C00668',
'C00794',
'C00795',
'C00880',
'C00984',
'C01097',
'C01113',
'C01132',
'C01216',
'C01235',
'C01286',
'C01613',
'C01697',
'C02262',
'C02669',
'C03383',
'C03733',
'C03785',
'C05396',
'C05399',
'C05400',
'C05401',
'C05402',
'C05404',
'C05796',
'C06311',
'C06376',
'C06377'
]

taurine = [
'C00022',
'C00024',
'C00025',
'C00026',
'C00033',
'C00041',
'C00084',
'C00094',
'C00097',
'C00227',
'C00245',
'C00506',
'C00519',
'C00593',
'C00606',
'C01678',
'C01959',
'C03149',
'C05122',
'C05123',
'C05844',
'C06735',
'C14179',
'C19685']

pantothenate = [
'C00010',
'C00022',
'C00049',
'C00054',
'C00097',
'C00099',
'C00106',
'C00141',
'C00183',
'C00229',
'C00429',
'C00522',
'C00750',
'C00831',
'C00864',
'C00882',
'C00966',
'C01053',
'C01088',
'C01134',
'C02642',
'C03492',
'C03688',
'C04079',
'C04272',
'C04352',
'C05665',
'C05944',
'C06010',
'C18911']

# %%
compounds_list = [arginine, valine, phenylalanine, glutathione, tyrosine, glycine, arginine_proline, purine, galactose, taurine, pantothenate]
pathways_names = [
'Arginine biosynthesis',
'Valine, leucine and isoleucine biosynthesis',
'Phenylalanine metabolism',
'Glutathione metabolism',
'Phenylalanine, tyrosine and tryptophan biosynthesis',
'Glycine, serine and threonine metabolism',
'Arginine and proline metabolism',
'Purine metabolism',
'Galactose metabolism',
'Taurine and hypotaurine metabolism',
'Pantothenate and CoA biosynthesis']

metabolites = pd.DataFrame()

for compounds, name in zip(compounds_list, pathways_names):
    temp = df[df['KEGG'].isin(compounds)].reset_index(drop=True)
    temp['Pathway'] = name

    metabolites = pd.concat([metabolites, temp], axis=0, ignore_index=True)

# %%
metabolites = metabolites[['Query', 'Match', 'KEGG', 'Pathway']]

# %%
metabolites
# Out:
#                                   Query                                Match  \
# 0                     n-acetylornithine                   N2-Acetylornithine
# 1                            citrulline                           Citrulline
# 2                             ornithine                            Ornithine
# 3                 n-acetylglutamic acid             N-Acetyl-L-glutamic acid
# 4                       l-aspartic acid                      L-Aspartic acid
# 5   n-acetyl-l-glutamate 5-semialdehyde  N-Acetyl-L-glutamate 5-semialdehyde
# 6                            l-arginine                           L-Arginine
# 7                    2-ketobutyric acid                   2-Ketobutyric acid
# 8                              l-valine                             L-Valine
# 9                           l-threonine                          L-Threonine
# 10                2-isopropylmalic acid                2-Isopropylmalic acid
# ...

# %%
metabolites.to_csv('../../data/processed/metabolites_from_pathways.csv', index=False, sep=';')
