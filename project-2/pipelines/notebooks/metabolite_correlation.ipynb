# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Differential metabolites

# %%
df = pd.read_csv('../../data/interim/volcano.csv', sep=',')
df.columns = ['Name'] + [*df.columns[1:]]

# %% [markdown]
# Metabolites concentration (processed in MetaboAnalyst)

# %%
metabolites = pd.read_csv('../../data/interim/data_processed.csv')

metabolites = metabolites.T.reset_index()
metabolites.columns = metabolites.loc[0, :]
metabolites = metabolites.iloc[1:, 1:].reset_index(drop=True)
metabolites.columns = [i.lower() for i in metabolites.columns]

# %%
metabolites.head()
# Out:
#   label 10-hendecenoic acid 10z-heptadecenoic acid 11z,14z-eicosadienoic acid  \
# 0   0.0         4686874.929            7092072.291                8058316.799
# 1   0.0         655182.6377            2214007.222                3461939.008
# 2   0.0         2940908.344            32554253.28                32534081.84
# 3   0.0         3141987.081            29856492.08                38315618.82
# 4   0.0         3505000.959            8301731.722                13603285.96
#
#   12,13-dihome 1,3,7-trimethyluric acid 1,3-dimethyluric acid  \
# 0  256120.2806              543306.7341           413815.1176
# 1  303809.6006              225880.1611           77351.83713
# 2  89327.45472              459436.0412           514826.5264
# 3  90695.13577                 0.000007              0.000005
# 4   369595.199              105866.4467           60785.23744
#
#   13z,16z-docosadienoic acid 1,5-anhydrosorbitol 1,7-dimethyluric acid  ...  \
# 0                362533.4409         28869691.33           1298981.871  ...
# 1                149766.6747         27060211.05           612956.9643  ...
# 2                1323705.934         27217750.57           2555543.527  ...
# 3                1153906.645         36344653.65           56885.01184  ...
# 4                594964.3357         24261268.65           1217437.156  ...
#
#     x-25952      x-25957     x-26008      x-26054      x-26062      x-26097  \
# 0  0.000001  2864228.254    492160.0  89810.87056  554066.4852  487905.8464
# 1  0.000002  2172276.086  11671617.0  132492.7808  185170.0093  535808.5113
# 2  0.000009      0.00001     0.00001  94774.35869  6966486.268  518254.7727
# 3  0.000005     0.000005     0.00001  160832.0697  171295.1869  381617.5823
# 4  0.000004  2474208.228  680933.854  107618.0136  249298.5664  400156.3026
#
#        x-26107      x-26109      x-26111      x-26119
# 0  590713.1672  59251.36317  4983490.209  51445.42412
# 1  353063.3959  92448.78365  3329895.601  171747.8975
# 2  1303573.687  34731.65998    2448117.7     0.000001
# 3   1416310.12  109688.6458  500611.5144   126388.841
# 4  452299.5297  25426.54941  9022154.386     0.000007
#
# [5 rows x 1483 columns]

# %% [markdown]
# Concentration on differential metabolites

# %%
metabolites = pd.concat([metabolites.iloc[:, 0], metabolites.filter(df['Name'].str.lower())], axis=1)

# %%
metabolites
# Out:
#     label tauroursodeoxycholic acid sulfate (2) glucuronide of c10h18o2 (1)  \
# 0     0.0                              0.000007                 412634.7229
# 1     0.0                           35269.70912                    0.000001
# 2     0.0                           245751.5431                    0.000005
# 3     0.0                           46344.79776                    0.000001
# 4     0.0                              0.000007                 76486.49686
# ..    ...                                   ...                         ...
# 575   1.0                           47869.76602                 131252.2288
# 576   1.0                              0.000009                 246754.6191
# 577   1.0                           201588.0175                 84242.87395
# 578   1.0                              0.000008                    0.000003
# 579   1.0                           174138.9919                    0.000007
#
#     vanillic alcohol sulfate     sorbitol glucuronide of c10h18o2 (6)  \
# 0                39500.16387  79780392.74                    0.000005
# 1                126171.1509  20195641.33                  26173.0273
# 2                45653.53487  21167802.38                    0.000002
# 3                   0.000005  6266042.196                     0.00001
# 4                60232.78586  6913646.782                    0.000002
# ..                       ...          ...                         ...
# 575                 0.000008  15474370.25                    0.000007
# 576                 0.000002  12786421.45                    0.000002
# 577                 0.000008  7714493.454                    0.000008
# 578                 0.000001  23579050.25                    0.000001
# 579              139998.7825  114238966.3                    0.000006
#
#     allopurinol riboside 2,3-diphosphoglyceric acid oxypurinol  \
# 0               0.000004                38257.17546   0.000007
# 1               0.000009                26165.34679   0.000005
# 2               0.000006                50673.12044   0.000004
# 3               0.000003                21785.37272   0.000007
# 4               0.000002                55850.17405   0.000007
# ..                   ...                        ...        ...
# 575             0.000005                66605.39252   0.000003
# 576             0.000007                   0.000007   0.000004
# 577              0.00001                40873.03489   0.000006
# 578             0.000003                84981.92538   0.000004
# 579             0.000001                   0.000003    0.00001
#
#     genistein sulfate  ... raltegravir   x-25396 glucuronide of c10h14o2 (4)  \
# 0            0.000009  ...     0.00001  0.000007                    0.000006
# 1         324683.5353  ...     0.00001   0.00001                    0.000006
# 2            0.000009  ...    0.000008  0.000009                    0.000007
# 3            0.000006  ...     0.00001  0.000001                    0.000006
# 4            0.000002  ...    0.000007  0.000003                    0.000003
# ..                ...  ...         ...       ...                         ...
# 575       81327.62403  ...    0.000008  0.000008                    0.000001
# 576          0.000003  ...    0.000006  0.000007                    0.000005
# 577          0.000007  ...    0.000004  0.000005                    0.000001
# 578       81407.29533  ...     0.00001  0.000001                    0.000004
# 579          0.000005  ...    0.000008  0.000008                    0.000004
#
#      warfarin 6-hydroxywarfarin 7-hydroxywarfarin doxylamine  \
# 0    0.000007          0.000004          0.000002   0.000008
# 1    0.000004          0.000008           0.00001   0.000009
# 2     0.00001          0.000008          0.000008   0.000003
# 3    0.000005          0.000006          0.000001   0.000008
# 4    0.000005          0.000004          0.000009   0.000007
# ..        ...               ...               ...        ...
# 575  0.000006          0.000001          0.000005   0.000003
# 576  0.000007          0.000001          0.000003   0.000005
# 577  0.000004           0.00001          0.000002   0.000003
# 578  0.000008          0.000008          0.000006    0.00001
# 579  0.000008          0.000004          0.000001   0.000009
#
#     3-methoxytyramine sulfate methylnaphthyl sulfate (1)  tramadol
# 0                 31367.05195                    0.00001  0.000001
# 1                 28221.46753                   0.000009  0.000003
# 2                 24307.72727                   0.000006  0.000006
# 3                  20999.7013                   0.000007  0.000009
# 4                 44987.36364                   0.000007  0.000006
# ..                        ...                        ...       ...
# 575                  0.000007                   0.000003  0.000002
# 576                77518.0854                   0.000008  0.000007
# 577               33974.06651                   0.000006  0.000003
# 578                  0.000005                   0.000009  0.000003
# 579               3698032.385                   0.000001  0.000003
#
# [580 rows x 33 columns]

# %% [markdown]
# Create two dataframes, one for healthy subjects, and the other for cancer patients

# %%
cancer = metabolites[metabolites['label'] == 0].drop('label', axis=1).reset_index(drop=True)
healthy = metabolites[metabolites['label'] == 1].drop('label', axis=1).reset_index(drop=True)

# %%
cancer
# Out:
#     tauroursodeoxycholic acid sulfate (2) glucuronide of c10h18o2 (1)  \
# 0                                0.000007                 412634.7229
# 1                             35269.70912                    0.000001
# 2                             245751.5431                    0.000005
# 3                             46344.79776                    0.000001
# 4                                0.000007                 76486.49686
# ..                                    ...                         ...
# 308                           62482.49273                    0.000007
# 309                           28789.25263                    0.000003
# 310                              0.000005                    0.000003
# 311                              0.000008                    0.000009
# 312                              0.000009                    0.000003
#
#     vanillic alcohol sulfate     sorbitol glucuronide of c10h18o2 (6)  \
# 0                39500.16387  79780392.74                    0.000005
# 1                126171.1509  20195641.33                  26173.0273
# 2                45653.53487  21167802.38                    0.000002
# 3                   0.000005  6266042.196                     0.00001
# 4                60232.78586  6913646.782                    0.000002
# ..                       ...          ...                         ...
# 308                 0.000005  6882474.123                    0.000006
# 309                 0.000001  10612436.25                    0.000006
# 310                 0.000004  3474853.814                    0.000003
# 311                68066.302  7503207.061                    0.000009
# 312              119679.7292   8810261.09                    0.000008
#
#     allopurinol riboside 2,3-diphosphoglyceric acid oxypurinol  \
# 0               0.000004                38257.17546   0.000007
# 1               0.000009                26165.34679   0.000005
# 2               0.000006                50673.12044   0.000004
# 3               0.000003                21785.37272   0.000007
# 4               0.000002                55850.17405   0.000007
# ..                   ...                        ...        ...
# 308             0.000007                 27587.1348   0.000001
# 309             0.000009                19861.84363   0.000004
# 310             0.000003                55944.84436   0.000001
# 311              0.00001                90570.45369   0.000004
# 312             0.000008                62081.52306   0.000008
#
#     genistein sulfate vanillactic acid  ... raltegravir   x-25396  \
# 0            0.000009      86425.70743  ...     0.00001  0.000007
# 1         324683.5353      63076.25962  ...     0.00001   0.00001
# 2            0.000009      149079.9891  ...    0.000008  0.000009
# 3            0.000006      61211.99872  ...     0.00001  0.000001
# 4            0.000002       68816.6996  ...    0.000007  0.000003
# ..                ...              ...  ...         ...       ...
# 308       111942.3692      43962.53136  ...    0.000006   0.00001
# 309          0.000005       158660.594  ...    0.000007  0.000002
# 310          0.000008      40783.07761  ...    0.000006  0.000006
# 311       74520.62001       58234.7189  ...    0.000003   0.00001
# 312          0.000006      49759.42653  ...    0.000008  0.000005
#
#     glucuronide of c10h14o2 (4)  warfarin 6-hydroxywarfarin 7-hydroxywarfarin  \
# 0                      0.000006  0.000007          0.000004          0.000002
# 1                      0.000006  0.000004          0.000008           0.00001
# 2                      0.000007   0.00001          0.000008          0.000008
# 3                      0.000006  0.000005          0.000006          0.000001
# 4                      0.000003  0.000005          0.000004          0.000009
# ..                          ...       ...               ...               ...
# 308                    0.000002  0.000002          0.000009          0.000003
# 309                    0.000008   0.00001          0.000005          0.000009
# 310                    0.000003  0.000006          0.000007          0.000007
# 311                    0.000001  0.000003          0.000007          0.000001
# 312                    0.000005  0.000002          0.000002          0.000002
#
#       doxylamine 3-methoxytyramine sulfate methylnaphthyl sulfate (1)  \
# 0       0.000008               31367.05195                    0.00001
# 1       0.000009               28221.46753                   0.000009
# 2       0.000003               24307.72727                   0.000006
# 3       0.000008                20999.7013                   0.000007
# 4       0.000007               44987.36364                   0.000007
# ..           ...                       ...                        ...
# 308      0.00001               25774.48333                   0.000002
# 309     0.000005               30073.43675                   0.000007
# 310  662960.4926                  0.000001                   0.000009
# 311      0.00001                  0.000009                   0.000005
# 312     0.000008                  0.000005                   0.000005
#
#      tramadol
# 0    0.000001
# 1    0.000003
# 2    0.000006
# 3    0.000009
# 4    0.000006
# ..        ...
# 308  0.000007
# 309  0.000004
# 310  0.000008
# 311  0.000001
# 312  0.000008
#
# [313 rows x 32 columns]

# %%
healthy
# Out:
#     tauroursodeoxycholic acid sulfate (2) glucuronide of c10h18o2 (1)  \
# 0                              34729.3522                    0.000005
# 1                             190655.1915                    0.000008
# 2                                0.000001                  121516.943
# 3                                0.000008                 595192.9372
# 4                                0.000005                    0.000002
# ..                                    ...                         ...
# 262                           47869.76602                 131252.2288
# 263                              0.000009                 246754.6191
# 264                           201588.0175                 84242.87395
# 265                              0.000008                    0.000003
# 266                           174138.9919                    0.000007
#
#     vanillic alcohol sulfate     sorbitol glucuronide of c10h18o2 (6)  \
# 0                   0.000007  16207834.17                     0.00001
# 1                   0.000004  22724738.18                    0.000002
# 2                   0.000005  4927776.731                    0.000008
# 3                512694.8727  4153261.581                    0.000008
# 4                35973.97486  10751713.97                    0.000004
# ..                       ...          ...                         ...
# 262                 0.000008  15474370.25                    0.000007
# 263                 0.000002  12786421.45                    0.000002
# 264                 0.000008  7714493.454                    0.000008
# 265                 0.000001  23579050.25                    0.000001
# 266              139998.7825  114238966.3                    0.000006
#
#     allopurinol riboside 2,3-diphosphoglyceric acid oxypurinol  \
# 0               0.000004                30805.14236   0.000003
# 1               0.000002                43956.51432   0.000004
# 2               0.000008                   0.000001   0.000004
# 3               0.000002                55306.75076   0.000006
# 4               0.000004                   0.000001   0.000004
# ..                   ...                        ...        ...
# 262             0.000005                66605.39252   0.000003
# 263             0.000007                   0.000007   0.000004
# 264              0.00001                40873.03489   0.000006
# 265             0.000003                84981.92538   0.000004
# 266             0.000001                   0.000003    0.00001
#
#     genistein sulfate vanillactic acid  ... raltegravir   x-25396  \
# 0            0.000009      62505.22475  ...    0.000004  0.000007
# 1            0.000003      52278.38215  ...    0.000009  0.000004
# 2         57058.38711       64027.9844  ...    0.000005  0.000003
# 3            0.000002      89617.48443  ...     0.00001   0.00001
# 4            0.000003       163649.076  ...    0.000002  0.000008
# ..                ...              ...  ...         ...       ...
# 262       81327.62403      130546.5668  ...    0.000008  0.000008
# 263          0.000003      107618.6578  ...    0.000006  0.000007
# 264          0.000007      108525.6799  ...    0.000004  0.000005
# 265       81407.29533      104156.3692  ...     0.00001  0.000001
# 266          0.000005      11662054.72  ...    0.000008  0.000008
#
#     glucuronide of c10h14o2 (4)     warfarin 6-hydroxywarfarin  \
# 0                      0.000008     0.000008          0.000003
# 1                       0.00001   28042441.0       332378.4655
# 2                      0.000003     0.000001          0.000006
# 3                      0.000001     0.000001          0.000007
# 4                      0.000009  74389207.44       1170119.534
# ..                          ...          ...               ...
# 262                    0.000001     0.000006          0.000001
# 263                    0.000005     0.000007          0.000001
# 264                    0.000001     0.000004           0.00001
# 265                    0.000004     0.000008          0.000008
# 266                    0.000004     0.000008          0.000004
#
#     7-hydroxywarfarin doxylamine 3-methoxytyramine sulfate  \
# 0            0.000005   0.000006                   19451.0
# 1         1344218.316   0.000003               17181.63636
# 2            0.000008   0.000001               54207.98701
# 3            0.000008   0.000003               27558.62338
# 4         5900117.684    0.00001               41289.06494
# ..                ...        ...                       ...
# 262          0.000005   0.000003                  0.000007
# 263          0.000003   0.000005                77518.0854
# 264          0.000002   0.000003               33974.06651
# 265          0.000006    0.00001                  0.000005
# 266          0.000001   0.000009               3698032.385
#
#     methylnaphthyl sulfate (1)  tramadol
# 0                     0.000009  0.000009
# 1                     0.000002  0.000003
# 2                     0.000003  0.000007
# 3                     0.000007  0.000001
# 4                     0.000004  0.000003
# ..                         ...       ...
# 262                   0.000003  0.000002
# 263                   0.000008  0.000007
# 264                   0.000006  0.000003
# 265                   0.000009  0.000003
# 266                   0.000001  0.000003
#
# [267 rows x 32 columns]

# %% [markdown]
# Metabolite correlation matrix

# %%
cancer_corr = cancer.corr(method='pearson', numeric_only=False)
healthy_corr = healthy.corr(method='pearson', numeric_only=False)

# %% [markdown]
# Present the matrix as an "adjacency list"

# %%
cancer_corr = cancer_corr.where(np.triu(np.ones(cancer_corr.shape)).astype(bool)).stack()
cancer_corr.index.names = ['source', 'target']
cancer_corr = cancer_corr.reset_index()
cancer_corr.columns = ['source', 'target', 'correlation']

cancer_edges = cancer_corr[cancer_corr['source'] != cancer_corr['target']]

# %%
cancer_edges
# Out:
#                                     source                       target  \
# 1    tauroursodeoxycholic acid sulfate (2)  glucuronide of c10h18o2 (1)
# 2    tauroursodeoxycholic acid sulfate (2)     vanillic alcohol sulfate
# 3    tauroursodeoxycholic acid sulfate (2)                     sorbitol
# 4    tauroursodeoxycholic acid sulfate (2)  glucuronide of c10h18o2 (6)
# 5    tauroursodeoxycholic acid sulfate (2)         allopurinol riboside
# ..                                     ...                          ...
# 520                             doxylamine   methylnaphthyl sulfate (1)
# 521                             doxylamine                     tramadol
# 523              3-methoxytyramine sulfate   methylnaphthyl sulfate (1)
# 524              3-methoxytyramine sulfate                     tramadol
# 526             methylnaphthyl sulfate (1)                     tramadol
#
#      correlation
# 1      -0.016385
# 2       0.067483
# 3      -0.011163
# 4      -0.006136
# 5       0.080747
# ..           ...
# 520    -0.025701
# 521     0.041094
# 523     0.079074
# 524     0.030371
# 526    -0.030291
#
# [496 rows x 3 columns]

# %%
healthy_corr = healthy_corr.where(np.triu(np.ones(healthy_corr.shape)).astype(bool)).stack()
healthy_corr.index.names = ['source', 'target']
healthy_corr = healthy_corr.reset_index()
healthy_corr.columns = ['source', 'target', 'correlation']

healthy_edges = healthy_corr[healthy_corr['source'] != healthy_corr['target']]

# %%
healthy_edges[abs(healthy_edges['correlation']) > 0.5]
# Out:
#                           source                       target  correlation
# 42   glucuronide of c10h18o2 (1)  glucuronide of c10h18o2 (7)     0.527506
# 49   glucuronide of c10h18o2 (1)  glucuronide of c10h18o2 (8)     0.779494
# 52   glucuronide of c10h18o2 (1)  glucuronide of c10h14o2 (7)     0.500474
# 152         allopurinol riboside                   oxypurinol     0.870715
# 159         allopurinol riboside                  allopurinol     0.537570
# 210                   oxypurinol                  allopurinol     0.588532
# 304  glucuronide of c10h18o2 (7)  glucuronide of c10h18o2 (8)     0.787312
# 307  glucuronide of c10h18o2 (7)  glucuronide of c10h14o2 (7)     0.840015
# 310  glucuronide of c10h18o2 (7)  glucuronide of c10h14o2 (4)     0.668600
# 322               maltol sulfate                 glucoheptose     0.589383
# 326               maltol sulfate  4-vinylguaiacol glucuronide     0.551062
# 410          o-desmethylnaproxen                     naproxen     0.511204
# 426  glucuronide of c10h18o2 (8)  glucuronide of c10h14o2 (7)     0.639502
# 465  glucuronide of c10h14o2 (7)  glucuronide of c10h14o2 (4)     0.762173
# 501                     warfarin            6-hydroxywarfarin     0.898827
# 502                     warfarin            7-hydroxywarfarin     0.901872
# 508            6-hydroxywarfarin            7-hydroxywarfarin     0.959308

# %%
cancer_edges[abs(cancer_edges['correlation']) > 0.5]
# Out:
#                           source                       target  correlation
# 40   glucuronide of c10h18o2 (1)             vanillactic acid     0.740148
# 42   glucuronide of c10h18o2 (1)  glucuronide of c10h18o2 (7)     0.991587
# 43   glucuronide of c10h18o2 (1)               maltol sulfate     0.746862
# 49   glucuronide of c10h18o2 (1)  glucuronide of c10h18o2 (8)     0.982409
# 51   glucuronide of c10h18o2 (1)  4-vinylguaiacol glucuronide     0.608213
# 152         allopurinol riboside                   oxypurinol     0.851859
# 159         allopurinol riboside                  allopurinol     0.572442
# 210                   oxypurinol                  allopurinol     0.655975
# 254             vanillactic acid  glucuronide of c10h18o2 (7)     0.772057
# 255             vanillactic acid               maltol sulfate     0.710093
# 261             vanillactic acid  glucuronide of c10h18o2 (8)     0.700410
# 263             vanillactic acid  4-vinylguaiacol glucuronide     0.854152
# 298  glucuronide of c10h18o2 (7)               maltol sulfate     0.754126
# 304  glucuronide of c10h18o2 (7)  glucuronide of c10h18o2 (8)     0.974690
# 306  glucuronide of c10h18o2 (7)  4-vinylguaiacol glucuronide     0.641640
# 324               maltol sulfate  glucuronide of c10h18o2 (8)     0.705888
# 326               maltol sulfate  4-vinylguaiacol glucuronide     0.703114
# 410          o-desmethylnaproxen                     naproxen     0.556464
# 425  glucuronide of c10h18o2 (8)  4-vinylguaiacol glucuronide     0.574304
# 465  glucuronide of c10h14o2 (7)  glucuronide of c10h14o2 (4)     0.973465
# 501                     warfarin            6-hydroxywarfarin     0.913407
# 502                     warfarin            7-hydroxywarfarin     0.949906
# 508            6-hydroxywarfarin            7-hydroxywarfarin     0.984329

# %%
healthy_edges.to_csv('../../data/processed/healthy_corr_edges.csv', index=False, sep=';')
cancer_edges.to_csv('../../data/processed/cancer_corr_edges.csv', index=False, sep=';')
